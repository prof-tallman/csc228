# %% [markdown]
# # The Vigenère Cipher #
#
# This notebook helps to encrypt and decrypt with the Vigenère cipher. The contents are much shorter than previous notebooks, for two reasons:
#
# 1. By now, you probably understand how these notebooks work and just want to get straight to the code, rather than reading Prof. Tallman's explanations.
# 2. The Vigenère Cipher is based on the Caesar Shift Cipher, which we already have learned.
# 3. We are only encrypting and decrypting with the Vigenère Cipher, there is no cryptanalysis (which is always the most confusing part).

# %%
# !wget -q -O vigenere.py https://raw.githubusercontent.com/prof-tallman/csc228/refs/heads/main/code/vigenere.py
# !wget -q -O caesar.py https://raw.githubusercontent.com/prof-tallman/csc228/refs/heads/main/code/caesar.py
import vigenere

print(">>> Import Complete\n\n")

# %%
password = "eagles"
plaintext = """In a hole in the ground there lived a hobbit. Not a nasty, dirty, wet hole,
filled with the ends of worms and an oozy smell, nor yet a dry, bare, sandy hole
with nothing in it to sit down on or to eat: it was a hobbit-hole, and that
means comfort."""

vigenere.show_encrypt(plaintext, password)

# %%
password = "eagles"
plaintext = """MN G SSDI IT ELW KRUFRV XHKCI DMVKO E ZSBHTX. FST G YEKXY, JTVLC, WKE LGPE,
LTPDID CTXZ XHK PRVW OL HSJQS GYH SR OUKC KQERW, RGV YKE E VVY, HLVW, WATOC ZSLK
HMLL NUELARG OY ML XO YTX VSWT ZR GV TU PEL: MT CLW S LOHMML-LORP, EFH TNLX
EIATD GGQFUCX."""

vigenere.show_decrypt(plaintext, password)
